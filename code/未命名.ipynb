# %%
from model.attention_module import Attention_Module
model = Attention_Module(3, 6)
print(model)
# from model.basic_blocks import ResidualBlock
# model = ResidualBlock(3, 10)
# print(model)
# Out:
# Attention_Module(
#   (first_residual_blocks): ResidualBlock(
#     (conv1): Conv2d(3, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(6, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace)
#     (conv4): Conv2d(3, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn4): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (trunk_branches): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(6, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
import torch
from torch import nn

x = torch.randn([1, 3, 28, 24])
model(x).shape
# Out:
# trunk shape torch.Size([1, 6, 28, 24])
# mask shape torch.Size([1, 6, 28, 24])
# torch.Size([1, 6, 28, 24])

# %%
from model.RRDB_Net import RRDB_Net
model = RRDB_Net(in_nc=3, out_nc=3, nf=64, nb=3)

# %%
x = torch.randn([1,3,28, 24])
model(x).shape
# Out:
# torch.Size([1, 64, 28, 24])

# %%
from model.RDDB_enhanced import RDDB_enhanced

# %%
model = RDDB_enhanced()
print(model)
x = torch.randn([1,3,28, 24])
model(x).shape
# Out:
# RDDB_enhanced(
#   (fea_conv): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (core): Sequential(
#     (0): Attention_Module(
#       (first_residual_blocks): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
# ...
